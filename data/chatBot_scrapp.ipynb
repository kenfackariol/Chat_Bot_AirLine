# %%
import pandas as pd 
import numpy as np 
import requests as rq

# URL de l'API
url = 'https://api.airfranceklm.com/opendata/flightstatus?startRange=2024-12-31T09:00:00Z&endRange=2024-12-31T23:59:59Z'


headers = {
    'API-Key': '8cvzmmhqczv5uvatzftekqzz',
    'Content-Type': 'application/x-www-form-urlencoded'
}

# requête GET pour récupérer les données
response = rq.get(url, headers=headers)

# Vérification du statut de la requête
if response.status_code == 200:
    
    dataFrame = response.json()  
    print(dataFrame)
else:
    print(f"Erreur {response.status_code}: Impossible de récupérer les données")
# Out:
# {'operationalFlights': [{'flightNumber': 871, 'flightScheduleDate': '2024-12-30', 'id': '20241230+FM+0871', 'haul': 'LONG', 'route': ['PVG', 'CDG', 'MRS'], 'airline': {'code': 'FM', 'name': 'SHANGHAI AIRLINES CO. LTD.'}, 'codeShareRelations': [{'marketingFlightNumber': 8585, 'flightScheduleDate': '2024-12-30', 'code': 'F', 'type': 'PASSENGER', 'airline': {'code': 'MU', 'name': 'CHINA EASTERN AIRLINES'}}], 'flightStatusPublic': 'ARRIVED', 'flightStatusPublicLangTransl': 'Arrived', 'flightLegs': [{'status': 'C', 'statusName': 'Cancelled', 'publishedStatus': 'CANCELLED', 'departureInformation': {'airport': {'code': 'PVG', 'name': 'PUDONG INTERNATIONAL AIRPORT', 'nameLangTranl': 'Pudong International Airport', 'city': {'code': 'SHA', 'name': 'SHANGHAI', 'nameLangTranl': 'Shanghai', 'country': {'areaCode': 'I', 'code': 'CN', 'name': 'CHINA', 'nameLangTranl': 'China', 'euroCountry': 'N', 'euCountry': 'N'}}, 'location': {'latitude': 31.15, 'longitude': 121.7833}, 'places': {'aerogareCode': 
# ...
